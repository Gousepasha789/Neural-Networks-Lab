# %% [markdown]
# <a href="https://colab.research.google.com/github/Gousepasha789/Neural-Networks-Lab/blob/main/Speed3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range for the universe of discourse
x = np.arange(0, 100, 1)

# Define trapezoidal membership function
def trapmf(x, a, b, c, d):

    return np.clip(np.minimum(np.minimum((x - a) / (b - a), (d - x) / (d - c)), 1.0), 0.0, 1.0)

# Define fuzzy set "Slow" using a trapezoidal membership function
Slow = trapmf(x, 0, 10, 20, 30)

# Define fuzzy set "Medium" using a trapezoidal membership function
Medium = trapmf(x, 30, 40, 50, 60)

# Define fuzzy set "Fast" using a trapezoidal membership function
Fast = trapmf(x, 60, 70, 80, 90)

# Plot fuzzy sets "Slow", "Medium", and "Fast"
plt.figure(figsize=(12, 6))
plt.plot(x, Slow, label='Slow', linewidth=2)
plt.plot(x, Medium, label='Medium', linewidth=2)
plt.plot(x, Fast, label='Fast', linewidth=2)
plt.xlabel('Speed (Kmph)')
plt.ylabel('Membership Degree')
plt.title('Fuzzy Sets for Speed Levels')
plt.legend()
plt.grid(True)
plt.show()
